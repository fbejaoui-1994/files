# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-eeeedb9e-0c8d-452b-9d83-1e240ad5098c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eeeedb9e-0c8d-452b-9d83-1e240ad5098c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d oles04/bundesliga-soccer-player
# Out:
# Dataset URL: https://www.kaggle.com/datasets/oles04/bundesliga-soccer-player
# License(s): other

# %%
# !unzip bundesliga-soccer-player.zip
# Out:
# Archive:  bundesliga-soccer-player.zip
#   inflating: bundesliga_player.csv

# %%
import pandas as pd
df = pd.read_csv('/content/bundesliga_player.csv')

# %%
df
# Out:
#      Unnamed: 0                name                  full_name  age  height  \
# 0             0        Manuel Neuer         Manuel Peter Neuer   37    1.93
# 1             1         Yann Sommer                        NaN   34    1.83
# 2             2        Sven Ulreich                        NaN   34    1.92
# 3             3     Johannes Schenk                        NaN   20    1.91
# 4             4    Matthijs de Ligt                        NaN   23    1.89
# ..          ...                 ...                        ...  ...     ...
# 510         510        Takuma Asano                      浅野 拓磨   28    1.73
# 511         511     Philipp Hofmann                        NaN   30    1.95
# 512         512        Simon Zoller        Simon Martin Zoller   31    1.79
# 513         513    Silvère Ganvoula  Silvère Ganvoula M'boussy   26    1.91
# 514         514  Moritz Broschinski                        NaN   22    1.90
#
# ...
