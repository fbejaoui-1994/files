# %%
import pandas as pd

# %%
import numpy as np
data = pd.read_csv('/content/Employee_Salary_Dataset.csv')

# %%
data
# Out:
#     ID  Experience_Years  Age  Gender    Salary
# 0    1                 5   28  Female    250000
# 1    2                 1   21    Male     50000
# 2    3                 3   23  Female    170000
# 3    4                 2   22    Male     25000
# 4    5                 1   17    Male     10000
# 5    6                25   62    Male   5001000
# 6    7                19   54  Female    800000
# 7    8                 2   21  Female      9000
# 8    9                10   36  Female     61500
# 9   10                15   54  Female    650000
# 10  11                 4   26  Female    250000
# 11  12                 6   29    Male   1400000
# 12  13                14   39    Male   6000050
# 13  14                11   40    Male    220100
# 14  15                 2   23    Male      7500
# 15  16                 4   27  Female     87000
# 16  17                10   34  Female    930000
# 17  18                15   54  Female   7900000
# 18  19                 2   21    Male     15000
# ...

# %%
data.describe()
# Out:
#               ID  Experience_Years        Age        Salary
# count  35.000000          35.00000  35.000000  3.500000e+01
# mean   18.000000           9.20000  35.485714  2.059147e+06
# std    10.246951           7.55295  14.643552  3.170124e+06
# min     1.000000           1.00000  17.000000  3.000000e+03
# 25%     9.500000           2.50000  22.500000  2.250000e+04
# 50%    18.000000           6.00000  29.000000  2.500000e+05
# 75%    26.500000          15.00000  53.500000  3.270000e+06
# max    35.000000          27.00000  62.000000  1.000000e+07

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                35 non-null     int64
#  1   Experience_Years  35 non-null     int64
#  2   Age               35 non-null     int64
#  3   Gender            35 non-null     object
#  4   Salary            35 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.5+ KB

# %%
data.shape
# Out:
# (35, 5)

# %%
data.columns
# Out:
# Index(['ID', 'Experience_Years', 'Age', 'Gender', 'Salary'], dtype='object')

# %%
print("salut")
# Out:
# salut

# %%
column_labels=data.columns
print(column_labels)
# Out:
# Index(['ID', 'Experience_Years', 'Age', 'Gender', 'Salary'], dtype='object')

# %%
data['Salary']
# Out:
# 0       250000
# 1        50000
# 2       170000
# 3        25000
# 4        10000
# 5      5001000
# 6       800000
# 7         9000
# 8        61500
# 9       650000
# 10      250000
# 11     1400000
# 12     6000050
# 13      220100
# 14        7500
# 15       87000
# 16      930000
# 17     7900000
# 18       15000
# 19      330000
# 20     6570000
# 21       25000
# 22     6845000
# 23        6000
# 24        8900
# 25       20000
# 26        3000
# 27    10000000
# 28     5000000
# 29        6100
# 30       80000
# 31      900000
# 32     1540000
# 33     9300000
# 34     7600000
# Name: Salary, dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
number_of_duplicates = data.duplicated().sum()

# %%
print(number_of_duplicates)
# Out:
# 0

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Experience_Years, Age, Gender, Salary]
# Index: []

# %%
data.head(7)
# Out:
#    ID  Experience_Years  Age  Gender   Salary
# 0   1                 5   28  Female   250000
# 1   2                 1   21    Male    50000
# 2   3                 3   23  Female   170000
# 3   4                 2   22    Male    25000
# 4   5                 1   17    Male    10000
# 5   6                25   62    Male  5001000
# 6   7                19   54  Female   800000

# %%
data.isnull().sum()
# Out:
# ID                  0
# Experience_Years    0
# Age                 0
# Gender              0
# Salary              0
# dtype: int64

# %%
len(data)
# Out:
# 35

# %%
number_of_null=data['Salary'].isnull().sum()

# %%
print(number_of_null)
# Out:
# 0

# %%
pourcentage_of_null=(number_of_null/len(data))*100

# %%
print(f"pourcentae de null {pourcentage_of_null:.2f}%")
# Out:
# pourcentae de null 0.00%

# %%
mean_salary=data['Salary'].mean()

# %%
print(f"la moyenne des salaires est {mean_salary:.2f}TND")
# Out:
# la moyenne des salaires est 2059147.14TND

# %%
median_salary=data['Salary'].median()

# %%
print(f"la mediane des salaires est {median_salary:.2f}TND")
# Out:
# la mediane des salaires est 250000.00TND

# %%
salary_range=data['Salary'].max()-data['Salary'].min()

# %%
print(f"la range des salaires est {salary_range:.2f}TND")
# Out:
# la range des salaires est 9997000.00TND

# %%
std_salary=data['Salary'].std()

# %%
print(f"l'ecart type des salaires est {std_salary:.2f}TND")
# Out:
# l'ecart type des salaires est 3170123.64TND

# %%
variance_salary=data['Salary'].var()

# %%
print(f"la variance des salaires est {variance_salary:.2f}")
# Out:
# la variance des salaires est 10049683866903.36

# %%
data['Salary'].max()
# Out:
# 10000000

# %%
data['Salary'].min()
# Out:
# 3000

# %%
q1=np.percentile(data['Salary'],25)
q2=np.percentile(data['Salary'],50)
q3=np.percentile(data['Salary'],75)

# %%
iqr=q3-q1

# %%
print(f"le premier quartile est {q1:.2f}TND")
print(f"le deuxieme quartile est {q2:.2f}TND")
print(f"le troisieme quartile est {q3:.2f}TND")
# Out:
# le premier quartile est 22500.00TND
# le deuxieme quartile est 250000.00TND
# le troisieme quartile est 3270000.00TND

# %%
print(f"l'interquartile range est {iqr:.2f}TND")
# Out:
# l'interquartile range est 3247500.00TND

# %%
upper_bound=q3+1.5*iqr
lower_bound=q1-1.5*iqr

# %%
print(f"la borne supérieure est {upper_bound:.2f}TND")
if lower_bound<0:
  print(f"la borne inférieure est 0 TND")
else:
  print(f"la borne inférieure est {lower_bound:.2f}TND")
# Out:
# la borne supérieure est 8141250.00TND
# la borne inférieure est 0 TND

# %%
outliers=data[(data['Salary']>upper_bound)|(data['Salary']<lower_bound)]

# %%
print(outliers)
# Out:
#     ID  Experience_Years  Age  Gender    Salary
# 27  28                27   62  Female  10000000
# 33  34                19   53  Female   9300000

# %%
percentage_outliers=(len(outliers)/len(data))*100

# %%
print(f'percentage_outliers:{percentage_outliers:.2f}%')
# Out:
# percentage_outliers:5.71%

# %%
print(data['Gender'].unique())
# Out:
# ['Female' 'Male']

# %%
gender_mode=data['Gender'].mode()[0]

# %%
print(f"le mode des sexes est {gender_mode}")
# Out:
# le mode des sexes est Female

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Calculate key statistics

minimum = data['Salary'].min()
maximum = data['Salary'].max()
# Calculate Pearson's Coefficient of Skewness
skewness = (3 * (mean_salary - median_salary)) / std_salary
# Determine skewness type
if skewness > 0:
    skew_text = "Right-Skewed (Positive Skewness)"
elif skewness < 0:
    skew_text = "Left-Skewed (Negative Skewness)"
else:
    skew_text = "Symmetric (No Skewness)"

# Set a modern theme
sns.set_theme(style="whitegrid", palette="pastel")

# Create the boxplot with enhanced aesthetics
plt.figure(figsize=(10, 6))
boxplot = sns.boxplot(x=data['Salary'], color="lightblue", width=0.5, fliersize=5, linewidth=2.5,
                      boxprops=dict(facecolor='lightblue', edgecolor='darkblue', linewidth=2.5),
                      whiskerprops=dict(color='darkblue', linewidth=2.5),
                      capprops=dict(color='darkblue', linewidth=2.5),
                      medianprops=dict(color='red', linewidth=2.5))

# Add text annotations with improved positioning and formatting
plt.text(q1, -0.2, f"Q1: {q1:.0f}", ha='center', fontsize=12, color='darkblue', bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))
plt.text(median_salary, -0.25, f"Median: {median_salary:.0f}", ha='center', fontsize=12, color='red', bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))
plt.text(q3, -0.2, f"Q3: {q3:.0f}", ha='center', fontsize=12, color='darkblue', bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))
plt.text(minimum, -0.3, f"Min: {minimum:.0f}", ha='center', fontsize=12, color='green', bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))
plt.text(maximum, -0.3, f"Max: {maximum:.0f}", ha='center', fontsize=12, color='green', bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))

# Display skewness result above the boxplot
plt.text(q3 + iqr, 0.4, f"Skewness: {skewness:.2f}\n{skew_text}", ha='center', fontsize=14, color='purple',
         bbox=dict(facecolor='white', alpha=0.8, edgecolor='none'))

# Format x-axis tick labels to avoid scientific notation
plt.ticklabel_format(style='plain', axis='x')

# Set plot title and labels with improved formatting
plt.title('Enhanced Boxplot of Salary (with Pearson Skewness)', fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Salary', fontsize=14, labelpad=10)
plt.ylabel('')

# Adjust y-axis limits to make space for annotations
plt.ylim(-0.35, 0.45)

# Remove y-axis ticks and labels for a cleaner look
plt.yticks([])

# Add a light grid for better readability
plt.grid(axis='x', linestyle='--', alpha=0.6)

# Show the plot
plt.show()

# %%
# Create the KDE plot with enhancements
plt.figure(figsize=(10, 6))
sns.kdeplot(data['Salary'], color='blue', fill=True, alpha=0.6, label='Salary Distribution')  # Fill under the curve

# Add vertical lines for key statistics
plt.axvline(mean_salary, color='red', linestyle='--', label=f'Mean: {mean_salary:.0f}')
plt.axvline(median_salary, color='green', linestyle='--', label=f'Median: {median_salary:.0f}')
plt.axvline(q1, color='purple', linestyle=':', label=f'Q1: {q1:.0f}')
plt.axvline(q3, color='orange', linestyle=':', label=f'Q3: {q3:.0f}')

# Add annotations for key statistics
plt.text(mean_salary, 0.0001, f'Mean: {mean_salary:.0f}', rotation=90, verticalalignment='bottom', color='red', fontsize=10)
plt.text(median_salary, 0.0001, f'Median: {median_salary:.0f}', rotation=90, verticalalignment='bottom', color='green', fontsize=10)
plt.text(q1, 0.0001, f'q1: {q1:.0f}', rotation=90, verticalalignment='bottom', color='purple', fontsize=10)
plt.text(q3, 0.0001, f'q3: {q3:.0f}', rotation=90, verticalalignment='bottom', color='orange', fontsize=10)

# Add title and labels
plt.title('Distribution of Salary (KDE)', fontsize=16, fontweight='bold')
plt.xlabel('Salary', fontsize=14)
plt.ylabel('Density', fontsize=14)

# Format x-axis tick labels to avoid scientific notation
plt.ticklabel_format(style='plain', axis='x')

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.6)

# Add legend
plt.legend(loc='upper right', fontsize=12)

# Show the plot
plt.show()
